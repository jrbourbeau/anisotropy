# %%
import matplotlib as mpl
import numpy as np
import healpy as hp

# %matplotlib inline

# %%
NSIDE = 32
m = np.arange(hp.nside2npix(NSIDE))
hp.mollview(m, title="Mollview image RING")

# %%
hp.mollview(m, nest=True, title="Mollview image NESTED")

# %%
mymap = hp.mollview(m, title="Mollview image RING")
print(mymap)
# Out:
# None

# %%
hp.write_map("my_map.fits", mymap)
